# %% [markdown]
# # What Are Variables?

# %% [markdown]
# ## Learning Objectives
#
# - Understand variables
# - Create variables
# - Assign values
# - Print variables
# - Follow naming rules

# %% [markdown]
# ## Theory
#
# Variables are names that refer to values stored in memory. They allow us to store and reuse data in a program.

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# ## Creating Variables

# %%
name = "Sachin"
age = 25

print(name)
print(age)
# Out:
# Sachin
# 25

# %% [markdown]
# ## Assigning Values

# %%
city = "Delhi"
country = "India"

print(city)
print(country)
# Out:
# Delhi
# India

# %% [markdown]
# ## Printing Variables

# %%
language = "Python"

print(language)
# Out:
# Python

# %% [markdown]
# ## Multiple Assignment

# %%
x, y, z = 10, 20, 30

print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ## Variable Types

# %%
name = "John"
age = 20
height = 5.8
student = True

print(type(name))
print(type(age))
print(type(height))
print(type(student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## Dynamic Typing

# %%
value = 100
print(value)

value = "Python"
print(value)
# Out:
# 100
# Python

# %% [markdown]
# ## Naming Rules

# %%
first_name = "Alice"
student_age = 21
_marks = 95

print(first_name)
print(student_age)
print(_marks)
# Out:
# Alice
# 21
# 95

# %% [markdown]
# ## Invalid Variable Names

# %%
# 2name = "John"
# first-name = "John"
# class = "Python"

print("Invalid examples are commented.")
# Out:
# Invalid examples are commented.

# %% [markdown]
# ## Constants

# %%
PI = 3.14159

print(PI)
# Out:
# 3.14159

# %% [markdown]
# ## Best Practices

# %%
student_name = "Rahul"
total_marks = 450
is_passed = True

print(student_name)
print(total_marks)
print(is_passed)
# Out:
# Rahul
# 450
# True

# %% [markdown]
# ## Common Mistakes

# %%
name = "Alice"

# Name = "Bob"

print(name)
# Out:
# Alice

# %% [markdown]
# ## Exercise
#
#
# Create variables for:
#
# - your_name
# - your_age
# - your_city
#
# Print all three values.

# %%
your_name = "Your Name"
your_age = 20
your_city = "Your City"

print(your_name)
print(your_age)
print(your_city)
# Out:
# Your Name
# 20
# Your City

# %% [markdown]
# ## Summary
#
# - Variables store values.
# - Python variables do not require a type declaration.
# - Use meaningful names.
# - Follow Python naming conventions.

# %% [markdown]
# ## Quiz
#
# **Which keyword is used to declare variables in Python?**
#
# 1. No keyword is required
# 2. var
# 3. let
# 4. const
